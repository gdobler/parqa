# %%
import pandas as pd

# %%
ExternalData = pd.read_csv('parqa/py/ZipcodeExternalDataSummary.csv')
parkQualitySummary = pd.read_csv('parqa/py/ParkQualityZipcode.csv')

# %%
ExternalData
ZipcodeParkQualityEternalData = pd.merge(parkQualitySummary,ExternalData, left_on='ZIPCODE', right_on='ZipCode5', how='left')

# %%
ZipcodeParkQualityEternalData
# Out:
#      ZIPCODE  Normalized Score     GEOID   NameofArea QualifyingName  \
# 0      10001          0.955859  10010001  10001 ZCTA5    10001 ZCTA5
# 1      10002          0.863230  10010002  10002 ZCTA5    10002 ZCTA5
# 2      10003          0.927281  10010003  10003 ZCTA5    10003 ZCTA5
# 3      10004          0.936243  10010004  10004 ZCTA5    10004 ZCTA5
# 4      10005          0.983889  10010005  10005 ZCTA5    10005 ZCTA5
# 5      10007          0.973775  10010007  10007 ZCTA5    10007 ZCTA5
# 6      10009          0.907813  10010009  10009 ZCTA5    10009 ZCTA5
# 7      10010          0.953302  10010010  10010 ZCTA5    10010 ZCTA5
# 8      10011          0.946098  10010011  10011 ZCTA5    10011 ZCTA5
# 9      10012          0.937661  10010012  10012 ZCTA5    10012 ZCTA5
# 10     10013          0.885107  10010013  10013 ZCTA5    10013 ZCTA5
# 11     10014          0.928510  10010014  10014 ZCTA5    10014 ZCTA5
# 12     10016          0.890716  10010016  10016 ZCTA5    10016 ZCTA5
# ...

# %%
ZipcodeParkQualityEternalData.to_csv('ZipcodeMainDataset.csv', sep=',')

# %% [markdown]
# # Creating Ontology of 311 Park Names -> official park names
#
# This notebook creates a match dictionary between park names in 311 data and in NYC Parks official dataset.
# Using this dictionary we can match each park-related call to specific park or park District
#
# Here I am using [fuzzywuzzy module](https://github.com/seatgeek/fuzzywuzzy)

# %%
__author__ = "Philipp Kats"
__date__ = "2015_10_15"

import pandas as pd
import geopandas as gp
import numpy as np
import os
from fuzzywuzzy import process  ## fuzzy string match in python

# %pylab inline
PARQA = os.getenv('PARQA') #basic path
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# need to add: recreation centers,
#     todd lot, and remove PS

# %% [markdown]
# ## Getting 311 Data

# %%
calls = pd.read_csv(PARQA + '/data/311DPR.csv',encoding='utf8', na_values='Unspecified')
calls= calls[pd.notnull(calls['Park Facility Name'])]

# %%
callParks = calls[['Park Facility Name','Borough']].drop_duplicates()
calls[pd.notnull(calls['Park Facility Name'])]
callParks['cleanName'] = callParks['Park Facility Name'].str.lower()
print '311_call_names total:', len(callParks['Park Facility Name'])
# Out:
# 311_call_names total: 1666

# %%
callParks.head()
# Out:
#                             Park Facility Name    Borough  \
# 1          Geo Soilan Park - Battery Park City  MANHATTAN
# 2                              Brookville Park     QUEENS
# 5                                Highland Park   BROOKLYN
# 10         Prospect Park - East Parade Grounds   BROOKLYN
# 11  Central Park - East 96th Street Playground  MANHATTAN
#
#                                      cleanName
# 1          geo soilan park - battery park city
# 2                              brookville park
# 5                                highland park
# 10         prospect park - east parade grounds
# 11  central park - east 96th street playground

# %%
borrowCode = pd.DataFrame({'Borough':['BROOKLYN',
                                      'QUEENS',
                                      'MANHATTAN',
                                      'BRONX',
                                      'STATEN ISLAND',
                                      'Unspecified'],
                           'code':['B',
                                   'Q',
                                   'M',
                                   'X',
                                   'R',
                                   '?']})

callParks = callParks.merge(borrowCode, how='left', on='Borough')
callParks.head(3)
# Out:
#                     Park Facility Name    Borough  \
# 0  Geo Soilan Park - Battery Park City  MANHATTAN
# 1                      Brookville Park     QUEENS
# 2                        Highland Park   BROOKLYN
#
#                              cleanName code
# 0  geo soilan park - battery park city    M
# 1                      brookville park    Q
# 2                        highland park    B

# %% [markdown]
# ## Getting Park names

# %%
## using geojson produced of OPEN DATA 
parkNames = gp.read_file(PARQA + 'data/parks_computed.geojson')[['SIGNNAME','BOROUGH']].drop_duplicates()
parkNames['SIGNNAME'] = parkNames['SIGNNAME'].str.lower()
len(parkNames['SIGNNAME'].drop_duplicates())
# Out:
# 1787

# %%
#create a dictionary of parks for each borough 
#that will add accuracy and boost spead of search ( I hope)

ofParks = {k:[unicode(x) for x in list(v)] for k,v in parkNames.groupby("BOROUGH")["SIGNNAME"]}

tmp = []
for v in ofParks.values():
    tmp.extend(v)
ofParks['?'] = tmp   #['???'] ### to mark parks with unspecified Borough

print ofParks.keys()
# Out:
# [u'B', u'M', u'Q', u'R', u'X', '?']

# %%
# ofParks['B']

# %% [markdown]
# ## I. Direct matching

# %%
cParksMatched = callParks.merge(parkNames, how='left', left_on = 'cleanName', right_on='SIGNNAME', copy=1)
cParksMatched['Type'] = np.nan

# %%
len(cParksMatched[pd.notnull(cParksMatched.SIGNNAME)])
# Out:
# 714

# %%
cParksMatched.ix[(pd.notnull(cParksMatched.SIGNNAME)&pd.isnull(cParksMatched.Type)), 'Type'] = 'park_direct'

# %%
cParksMatched.head()
# Out:
#                     Park Facility Name    Borough  \
# 0  Geo Soilan Park - Battery Park City  MANHATTAN
# 1                      Brookville Park     QUEENS
# 2                        Highland Park   BROOKLYN
# 3                        Highland Park   BROOKLYN
# 4  Prospect Park - East Parade Grounds   BROOKLYN
#
#                              cleanName code         SIGNNAME BOROUGH  \
# 0  geo soilan park - battery park city    M              NaN     NaN
# 1                      brookville park    Q  brookville park       Q
# 2                        highland park    B    highland park       B
# 3                        highland park    B    highland park       Q
# 4  prospect park - east parade grounds    B              NaN     NaN
#
#           Type
# 0          NaN
# 1  park_direct
# 2  park_direct
# 3  park_direct
# 4          NaN

# %% [markdown]
# ## II. Empiric decoding

# %%
#some manual improvisation, based on emirical experience

def empiric(x):
    '''returns clean keyName if name contains 
    specific words (central park, for example)'''

    general = {'flushing meadows':'flushing meadows and corona park',
               'central park':'central park', 
               'prospect park':'prospect park',
               'greenbelt': 'greenbelt native plant center',
               'red hook park':'red hook recreation area',
               'crotona park':'crotona park',
               'marine park': 'marine park', 
               'van cortlandt':'van cortlandt park',
               'seravalli': 'corporal john a. seravalli playground',
               'inwood hill': 'inwood hill park',
               'forest park':'forest park',
               'pelham bay park':'pelham bay park',
               'kissena park': 'kissena park',
               'asser levy': 'asser levy park',
               'highland park':'highland park',
               'bronx park':'bronx park',
               '100 percent':'100% Playground',
               'seaside playground':'Seaside Playground',
               'dolen':'Owen F. Dolen Park',
               'loring':'Vito Locascio Field'
                }
    
    
    for k in general.keys():
        if k in x.cleanName:
            return general[k]
    return np.nan

# %%
cParksMatched.ix[pd.isnull(cParksMatched.SIGNNAME), 'SIGNNAME'] = cParksMatched.ix[pd.isnull(cParksMatched.SIGNNAME)].apply(empiric,1)

# %%
cParksMatched.ix[(pd.notnull(cParksMatched.SIGNNAME)&pd.isnull(cParksMatched.Type)), 'Type'] = 'empiric'

# %%
cParksMatched.head(10)
# Out:
#                            Park Facility Name    Borough  \
# 0         Geo Soilan Park - Battery Park City  MANHATTAN
# 1                             Brookville Park     QUEENS
# 2                               Highland Park   BROOKLYN
# 3                               Highland Park   BROOKLYN
# 4         Prospect Park - East Parade Grounds   BROOKLYN
# 5  Central Park - East 96th Street Playground  MANHATTAN
# 6                        Washington Hall Park   BROOKLYN
# 7                   Callahan-Kelly Playground   BROOKLYN
# 8                       William H Seward Park  MANHATTAN
# 9                 Col David Marcus Playground   BROOKLYN
#
#                                     cleanName code                   SIGNNAME  \
# 0         geo soilan park - battery park city    M                        NaN
# 1                             brookville park    Q            brookville park
# 2                               highland park    B              highland park
# 3                               highland park    B              highland park
# 4         prospect park - east parade grounds    B              prospect park
# 5  central park - east 96th street playground    M               central park
# 6                        washington hall park    B       washington hall park
# 7                   callahan-kelly playground    B  callahan-kelly playground
# 8                       william h seward park    M                        NaN
# 9                 col david marcus playground    B                        NaN
#
#   BOROUGH         Type
# 0     NaN          NaN
# 1       Q  park_direct
# 2       B  park_direct
# 3       Q  park_direct
# 4     NaN      empiric
# 5     NaN      empiric
# 6       B  park_direct
# 7       B  park_direct
# 8     NaN          NaN
# 9     NaN          NaN

# %%
print 'Recognized:'
print len(cParksMatched[pd.notnull(cParksMatched.SIGNNAME)]), '/', len(cParksMatched)
# Out:
# Recognized:
# 923 / 1678

# %% [markdown]
# ## III. Playgrounds

# %%
playgrounds = [x.decode('utf8') for x in pd.read_csv(PARQA + 'data/DPR_property/playgrounds.csv')['Name'].tolist()]

# %%
# cParksMatched[pd.isnull(cParksMatched.SIGNNAME)][cParksMatched.cleanName.str.contains('play')]

# %%
cParksMatched['match'] = np.nan
cParksMatched['ratio'] = np.nan

# %%
cParksMatched.ix[pd.isnull(cParksMatched.SIGNNAME) & cParksMatched.cleanName.str.contains('play'), 'Type'] = 'pgs'
cParksMatched.ix[cParksMatched.Type=='pgs', 'match'] = \
cParksMatched.ix[cParksMatched.Type=='pgs', 'cleanName'].apply(lambda x: process.extractOne(x, playgrounds))

# %%
cParksMatched.ix[cParksMatched.Type=='pgs', 'SIGNNAME'] = \
cParksMatched.ix[cParksMatched.Type=='pgs', 'match'].apply(lambda x: x[0])

cParksMatched.ix[cParksMatched.Type=='pgs', 'ratio'] = \
cParksMatched.ix[cParksMatched.Type=='pgs', 'match'].apply(lambda x: x[1])

# %%
cParksMatched[cParksMatched.Type=='pgs']
# Out:
#                                      Park Facility Name        Borough  \
# 9                           Col David Marcus Playground       BROOKLYN
# 13           Mccarren Park - Vincent V Abate Playground       BROOKLYN
# 24                            Harold L Ickes Playground       BROOKLYN
# 27                             Hoover Manton Playground         QUEENS
# 33                          Emerald Playground - PS 200         QUEENS
# 36                   Doctor Gertrude B Kelly Playground      MANHATTAN
# 46                              May Matthews Playground      MANHATTAN
# 47                               Cuyler Gore Playground       BROOKLYN
# 52                         Terrapin Playground - JHS 51       BROOKLYN
# 53                           Jamaica Playground - PS 40         QUEENS
# 56                                   Hancock Playground       BROOKLYN
# 68                                Bath Beach Playground       BROOKLYN
# 75                    Queens Valley Playground - PS 164         QUEENS
# 76                            Sumner Playground - PS 59       BROOKLYN
# 82                Riverside Park - Claremont Playground      MANHATTAN
# 95                            Mount Playground - PS 174         QUEENS
# 110                         Russell Pederson Playground       BROOKLYN
# 112                               Sol  Bloom Playground      MANHATTAN
# 113                 Cabbell Park and Cambria Playground         QUEENS
# 114                      Booker T Washington Playground      MANHATTAN
# 126                 Midland Beach - Playland Playground  STATEN ISLAND
# 129                            Pool - PS 186 Playground         QUEENS
# 131                         Dr Richard Green Playground       BROOKLYN
# 132                      East River Playground - PS 146      MANHATTAN
# 147                             Jamie Campiz Playground       BROOKLYN
# 153               Riverside Park - River Run Playground      MANHATTAN
# 155                                   Morton Playground          BRONX
# 157                           Mosholu Playground - PS 8          BRONX
# 163                      Riverdale Playground - JHS 141          BRONX
# 170   Jackie Robinson Park - Playground One Fifty Tw...      MANHATTAN
# ...                                                 ...            ...
# 1511                                     Playground 103      MANHATTAN
# 1514                    Seven Gables Playground - IS 74         QUEENS
# 1520                                  PS 125 Playground       BROOKLYN
# 1538                                  146 St Playground         QUEENS
# 1545                               De Salvio Playground      MANHATTAN
# 1559                  Pool - Mariners Harbor Playground  STATEN ISLAND
# 1560                        Sunrise Playground - PS 195       BROOKLYN
# 1562                      Pool - Bronx River Playground          BRONX
# 1564                                Sweetgum Playground          BRONX
# 1565                Aqueduct Walk - Rosewood Playground          BRONX
# 1590                     Leonardo Ingravallo Playground         QUEENS
# 1595                         Clawson Playground - PS 50  STATEN ISLAND
# 1612                  Queens Valley Playground - PS 164       BROOKLYN
# 1616                      Dr Ronald E McNair Playground         QUEENS
# 1629                  Hallets Point Playground - Area B         QUEENS
# 1636                    Lie Playground - Real Good Park         QUEENS
# 1641                             Stop and Go Playground          BRONX
# 1650                                 Catbird Playground      MANHATTAN
# 1651                       Drumgoole Tot Lot Playground  STATEN ISLAND
# 1652               Starlight Park - Plimpton Playground          BRONX
# 1653                        Seaside Playground - PS 225       BROOKLYN
# 1655                     Castlewood Playground - PS 186       BROOKLYN
# 1657                        Parkside Playground - Bronx          BRONX
# 1659                         M L King Houses Playground      MANHATTAN
# 1660                               Playground Fifty-Two          BRONX
# 1664                        Under The Tracks Playground       BROOKLYN
# 1665                        La Guardia Playground South       BROOKLYN
# 1667                                   Dyker Playground  STATEN ISLAND
# 1668                               Playground One-Forty         QUEENS
# 1677                                  PS 286 Playground       BROOKLYN
#
#                                               cleanName code  \
# 9                           col david marcus playground    B
# 13           mccarren park - vincent v abate playground    B
# 24                            harold l ickes playground    B
# 27                             hoover manton playground    Q
# 33                          emerald playground - ps 200    Q
# 36                   doctor gertrude b kelly playground    M
# 46                              may matthews playground    M
# 47                               cuyler gore playground    B
# 52                         terrapin playground - jhs 51    B
# 53                           jamaica playground - ps 40    Q
# 56                                   hancock playground    B
# 68                                bath beach playground    B
# 75                    queens valley playground - ps 164    Q
# 76                            sumner playground - ps 59    B
# 82                riverside park - claremont playground    M
# 95                            mount playground - ps 174    Q
# 110                         russell pederson playground    B
# 112                               sol  bloom playground    M
# 113                 cabbell park and cambria playground    Q
# 114                      booker t washington playground    M
# 126                 midland beach - playland playground    R
# 129                            pool - ps 186 playground    Q
# 131                         dr richard green playground    B
# 132                      east river playground - ps 146    M
# 147                             jamie campiz playground    B
# 153               riverside park - river run playground    M
# 155                                   morton playground    X
# 157                           mosholu playground - ps 8    X
# 163                      riverdale playground - jhs 141    X
# 170   jackie robinson park - playground one fifty tw...    M
# ...                                                 ...  ...
# 1511                                     playground 103    M
# 1514                    seven gables playground - is 74    Q
# 1520                                  ps 125 playground    B
# 1538                                  146 st playground    Q
# 1545                               de salvio playground    M
# 1559                  pool - mariners harbor playground    R
# 1560                        sunrise playground - ps 195    B
# 1562                      pool - bronx river playground    X
# 1564                                sweetgum playground    X
# 1565                aqueduct walk - rosewood playground    X
# 1590                     leonardo ingravallo playground    Q
# 1595                         clawson playground - ps 50    R
# 1612                  queens valley playground - ps 164    B
# 1616                      dr ronald e mcnair playground    Q
# 1629                  hallets point playground - area b    Q
# 1636                    lie playground - real good park    Q
# 1641                             stop and go playground    X
# 1650                                 catbird playground    M
# 1651                       drumgoole tot lot playground    R
# 1652               starlight park - plimpton playground    X
# 1653                        seaside playground - ps 225    B
# 1655                     castlewood playground - ps 186    B
# 1657                        parkside playground - bronx    X
# 1659                         m l king houses playground    M
# 1660                               playground fifty-two    X
# 1664                        under the tracks playground    B
# 1665                        la guardia playground south    B
# 1667                                   dyker playground    R
# 1668                               playground one-forty    Q
# 1677                                  ps 286 playground    B
#
#                                SIGNNAME BOROUGH Type  \
# 9       Col David Marcus Mem Playground     NaN  pgs
# 13           Vincent V Abate Playground     NaN  pgs
# 24              Harold Ickes Playground     NaN  pgs
# 27                    Manton Playground     NaN  pgs
# 33                           Playground     NaN  pgs
# 36       Dr Gertrude B Kelly Playground     NaN  pgs
# 46              May Matthews Playground     NaN  pgs
# 47                          Cuyler Gore     NaN  pgs
# 52                  Terrapin Playground     NaN  pgs
# 53           Jamaica Playground (ps 40)     NaN  pgs
# 56                   Hancock Playground     NaN  pgs
# 68                Bath Beach Playground     NaN  pgs
# 75             Queens Valley Playground     NaN  pgs
# 76                    Sumner Playground     NaN  pgs
# 82                            Claremont     NaN  pgs
# 95                           Playground     NaN  pgs
# 110         Russell Pederson Playground     NaN  pgs
# 112                Sol Bloom Playground     NaN  pgs
# 113                          Playground     NaN  pgs
# 114      Booker T Washington Playground     NaN  pgs
# 126            Midland Beach Playground     NaN  pgs
# 129                          Playground     NaN  pgs
# 131         Dr Richard Green Playground     NaN  pgs
# 132               East River Playground     NaN  pgs
# 147             Jaime Campiz Playground     NaN  pgs
# 153                River Run Playground     NaN  pgs
# 155                   Morton Playground     NaN  pgs
# 157                          Playground     NaN  pgs
# 163                          Playground     NaN  pgs
# 170                Jackie Robinson Park     NaN  pgs
# ...                                 ...     ...  ...
# 1511                Playground 103 CIII     NaN  pgs
# 1514            Seven Gables Playground     NaN  pgs
# 1520                  Ps 125 Playground     NaN  pgs
# 1538                     Playground 146     NaN  pgs
# 1545                Desalvio Playground     NaN  pgs
# 1559         Mariners Harbor Playground     NaN  pgs
# 1560                         Playground     NaN  pgs
# 1562                         Playground     NaN  pgs
# 1564                Sweetgum Playground     NaN  pgs
# 1565                         Playground     NaN  pgs
# 1590     Leonardo Ingravallo Playground     NaN  pgs
# 1595                 Clawson Playground     NaN  pgs
# 1612           Queens Valley Playground     NaN  pgs
# 1616    Dr. Ronald E. McNair Playground     NaN  pgs
# 1629  Hallets Point Playground (area B)     NaN  pgs
# 1636                               PARK     NaN  pgs
# 1641              Stop nd Go Playground     NaN  pgs
# 1650                 Catbird Playground     NaN  pgs
# 1651                         Playground     NaN  pgs
# 1652                         Playground     NaN  pgs
# 1653                         Playground     NaN  pgs
# 1655              Castlewood Playground     NaN  pgs
# 1657                Parkside Playground     NaN  pgs
# 1659                         Playground     NaN  pgs
# 1660               Playground Fifty-two     NaN  pgs
# 1664        Under The Tracks Playground     NaN  pgs
# 1665        La Guardia Playground South     NaN  pgs
# 1667                   Dyker Playground     NaN  pgs
# 1668               Playground One-forty     NaN  pgs
# 1677                  Ps 286 Playground     NaN  pgs
#
#                                         match  ratio
# 9       (Col David Marcus Mem Playground, 95)     95
# 13           (Vincent V Abate Playground, 90)     90
# 24              (Harold Ickes Playground, 96)     96
# 27                    (Manton Playground, 95)     95
# 33                           (Playground, 90)     90
# 36       (Dr Gertrude B Kelly Playground, 94)     94
# 46             (May Matthews Playground, 100)    100
# 47                          (Cuyler Gore, 90)     90
# 52                  (Terrapin Playground, 95)     95
# 53           (Jamaica Playground (ps 40), 98)     98
# 56                  (Hancock Playground, 100)    100
# 68               (Bath Beach Playground, 100)    100
# 75             (Queens Valley Playground, 95)     95
# 76                    (Sumner Playground, 95)     95
# 82                            (Claremont, 90)     90
# 95                           (Playground, 90)     90
# 110        (Russell Pederson Playground, 100)    100
# 112                (Sol Bloom Playground, 98)     98
# 113                          (Playground, 90)     90
# 114     (Booker T Washington Playground, 100)    100
# 126            (Midland Beach Playground, 95)     95
# 129                          (Playground, 90)     90
# 131        (Dr Richard Green Playground, 100)    100
# 132               (East River Playground, 95)     95
# 147             (Jaime Campiz Playground, 96)     96
# 153                (River Run Playground, 90)     90
# 155                  (Morton Playground, 100)    100
# 157                          (Playground, 90)     90
# 163                          (Playground, 90)     90
# 170                (Jackie Robinson Park, 90)     90
# ...                                       ...    ...
# 1511                (Playground 103 CIII, 95)     95
# 1514            (Seven Gables Playground, 95)     95
# 1520                 (Ps 125 Playground, 100)    100
# 1538                     (Playground 146, 95)     95
# 1545                (Desalvio Playground, 97)     97
# 1559         (Mariners Harbor Playground, 95)     95
# 1560                         (Playground, 90)     90
# 1562                         (Playground, 90)     90
# 1564               (Sweetgum Playground, 100)    100
# 1565                         (Playground, 90)     90
# 1590    (Leonardo Ingravallo Playground, 100)    100
# 1595                 (Clawson Playground, 95)     95
# 1612           (Queens Valley Playground, 95)     95
# 1616    (Dr. Ronald E. McNair Playground, 97)     97
# 1629  (Hallets Point Playground (area B), 98)     98
# 1636                               (PARK, 90)     90
# 1641              (Stop nd Go Playground, 98)     98
# 1650                (Catbird Playground, 100)    100
# 1651                         (Playground, 90)     90
# 1652                         (Playground, 90)     90
# 1653                         (Playground, 90)     90
# 1655              (Castlewood Playground, 95)     95
# 1657                (Parkside Playground, 95)     95
# 1659                         (Playground, 90)     90
# 1660              (Playground Fifty-two, 100)    100
# 1664       (Under The Tracks Playground, 100)    100
# 1665       (La Guardia Playground South, 100)    100
# 1667                  (Dyker Playground, 100)    100
# 1668              (Playground One-forty, 100)    100
# 1677                 (Ps 286 Playground, 100)    100
#
# [379 rows x 9 columns]

# %%
print 'Recognized:'
print len(cParksMatched[pd.notnull(cParksMatched.SIGNNAME)]), '/', len(cParksMatched)
# Out:
# Recognized:
# 1302 / 1678

# %% [markdown]
# ## IV. Pools

# %%
pools = [x.decode('utf8').lower() for x in pd.read_csv(PARQA + 'data/DPR_property/pools.csv')['Name'].tolist()]

# %%
cParksMatched.ix[pd.isnull(cParksMatched.SIGNNAME) & cParksMatched.cleanName.str.contains('pool'), 'Type'] = 'pool'
# cParksMatched[cParksMatched.Type=='pool']

# %%
cParksMatched.ix[cParksMatched.Type=='pool', 'match'] = \
cParksMatched.ix[cParksMatched.Type=='pool', 'cleanName'].apply(lambda x: process.extractOne(x, pools))

# %%
cParksMatched.ix[cParksMatched.Type=='pool', 'SIGNNAME'] = \
cParksMatched.ix[cParksMatched.Type=='pool', 'match'].apply(lambda x: x[0])

cParksMatched.ix[cParksMatched.Type=='pool', 'ratio'] = \
cParksMatched.ix[cParksMatched.Type=='pool', 'match'].apply(lambda x: x[1])

# %%
cParksMatched[cParksMatched.Type=='pool']
# Out:
#                                      Park Facility Name        Borough  \
# 140                          Pool - Metropolitan Avenue       BROOKLYN
# 156                 Pool - St. John's Recreation Center       BROOKLYN
# 179                Pool - Brownsville Recreation Center       BROOKLYN
# 218   Recreation Center - Metropolitan Pool and Fitn...       BROOKLYN
# 309                                  Pool - Hansborough      MANHATTAN
# 352                             Pool - JHS 57 and HS 26       BROOKLYN
# 416                              John Jay Park and Pool      MANHATTAN
# 482     Williamsbridge Oval - P G  Mini Pool and Courts          BRONX
# 602                                      Pool - Mullaly          BRONX
# 614                                Pool - Hamilton Fish      MANHATTAN
# 625                                        Pool - Mapes          BRONX
# 655                              Pool - Betsy Head Park       BROOKLYN
# 656                              Pool - Glenwood Houses       BROOKLYN
# 657                                 Pool - Fred Douglas      MANHATTAN
# 691                                     Pool - Dry Dock      MANHATTAN
# 694                                  Pool - Abe Lincoln      MANHATTAN
# 704                                 Pool - Astoria Park         QUEENS
# 708                           Pool - David Fox - PS 251       BROOKLYN
# 716                                   Pool - Highbridge      MANHATTAN
# 724                                       Pool - Wagner      MANHATTAN
# 728                                      Pool - Liberty         QUEENS
# 729                                  Pool - Tottenville  STATEN ISLAND
# 739                                  Pool - Roy Wilkins         QUEENS
# 744                                        Pool - Faber  STATEN ISLAND
# 745                                    Pool - Kosciusko       BROOKLYN
# 771                                     Pool - John Jay      MANHATTAN
# 778                             Pool - Thomas Jefferson      MANHATTAN
# 787                                      Pool - Crotona          BRONX
# 806                                    Pool - Claremont          BRONX
# 808                              Pool - Commodore Barry       BROOKLYN
# 813                                       Pool - Fisher         QUEENS
# 820                           Pool - Douglas and Degraw       BROOKLYN
# 828                              Pool - Tompkins Square      MANHATTAN
# 854                         Pool - Jackie Robinson Park      MANHATTAN
# 858                         Pool - Recreation Center 54      MANHATTAN
# 881                           Pool - Marcus Garvey Park      MANHATTAN
# 900                                     Pool - Bushwick       BROOKLYN
# 906                                Pool - Tony Dapolito      MANHATTAN
# 909                                Pool - West Brighton  STATEN ISLAND
# 912                                  Pool - Fort Totten         QUEENS
# 933                                        Pool - Lyons  STATEN ISLAND
# 939                                  Pool - Sunset Park       BROOKLYN
# 940                                       Pool - Howard       BROOKLYN
# 944                                       Pool - Haffen          BRONX
# 1329                        Pool - Sheltering Arms Park      MANHATTAN
# 1342                                   Pool - MacArthur  STATEN ISLAND
# 1381                                  Pool - Windmuller         QUEENS
# 1384                             Pool - Thompson Street      MANHATTAN
# 1399                                     Pool - Chelsea      MANHATTAN
# 1414                                  Pool - St. Mary's          BRONX
# 1442                                     Kosciusko Pool       BROOKLYN
# 1485                               Pool - McCarren Park       BROOKLYN
# 1495                               Pool - Lindower Park       BROOKLYN
# 1539                             Pool - Gertrude Ederle      MANHATTAN
# 1557                                       Pool - PS 10         QUEENS
# 1558                 Pool - Brooklyn Bridge Park Pop-Up       BROOKLYN
# 1614                            Pool - Marie Curie Park         QUEENS
# 1625                             Pool - Edenwald Houses          BRONX
#
#                                               cleanName code  \
# 140                          pool - metropolitan avenue    B
# 156                 pool - st. john's recreation center    B
# 179                pool - brownsville recreation center    B
# 218   recreation center - metropolitan pool and fitn...    B
# 309                                  pool - hansborough    M
# 352                             pool - jhs 57 and hs 26    B
# 416                              john jay park and pool    M
# 482     williamsbridge oval - p g  mini pool and courts    X
# 602                                      pool - mullaly    X
# 614                                pool - hamilton fish    M
# 625                                        pool - mapes    X
# 655                              pool - betsy head park    B
# 656                              pool - glenwood houses    B
# 657                                 pool - fred douglas    M
# 691                                     pool - dry dock    M
# 694                                  pool - abe lincoln    M
# 704                                 pool - astoria park    Q
# 708                           pool - david fox - ps 251    B
# 716                                   pool - highbridge    M
# 724                                       pool - wagner    M
# 728                                      pool - liberty    Q
# 729                                  pool - tottenville    R
# 739                                  pool - roy wilkins    Q
# 744                                        pool - faber    R
# 745                                    pool - kosciusko    B
# 771                                     pool - john jay    M
# 778                             pool - thomas jefferson    M
# 787                                      pool - crotona    X
# 806                                    pool - claremont    X
# 808                              pool - commodore barry    B
# 813                                       pool - fisher    Q
# 820                           pool - douglas and degraw    B
# 828                              pool - tompkins square    M
# 854                         pool - jackie robinson park    M
# 858                         pool - recreation center 54    M
# 881                           pool - marcus garvey park    M
# 900                                     pool - bushwick    B
# 906                                pool - tony dapolito    M
# 909                                pool - west brighton    R
# 912                                  pool - fort totten    Q
# 933                                        pool - lyons    R
# 939                                  pool - sunset park    B
# 940                                       pool - howard    B
# 944                                       pool - haffen    X
# 1329                        pool - sheltering arms park    M
# 1342                                   pool - macarthur    R
# 1381                                  pool - windmuller    Q
# 1384                             pool - thompson street    M
# 1399                                     pool - chelsea    M
# 1414                                  pool - st. mary's    X
# 1442                                     kosciusko pool    B
# 1485                               pool - mccarren park    B
# 1495                               pool - lindower park    B
# 1539                             pool - gertrude ederle    M
# 1557                                       pool - ps 10    Q
# 1558                 pool - brooklyn bridge park pop-up    B
# 1614                            pool - marie curie park    Q
# 1625                             pool - edenwald houses    X
#
#                        SIGNNAME BOROUGH  Type  \
# 140              claremont pool     NaN  pool
# 156   recreation center 54 pool     NaN  pool
# 179   recreation center 54 pool     NaN  pool
# 218           metropolitan pool     NaN  pool
# 309            hansborough pool     NaN  pool
# 352           jhs 57/hs 26 pool     NaN  pool
# 416              claremont pool     NaN  pool
# 482              claremont pool     NaN  pool
# 602                mullaly pool     NaN  pool
# 614          hamilton fish pool     NaN  pool
# 625                  mapes pool     NaN  pool
# 655             betsy head pool     NaN  pool
# 656        glenwood houses pool     NaN  pool
# 657                crotona pool     NaN  pool
# 691               dry dock pool     NaN  pool
# 694            abe lincoln pool     NaN  pool
# 704                crotona pool     NaN  pool
# 708       david fox/ps 251 pool     NaN  pool
# 716             highbridge pool     NaN  pool
# 724                 wagner pool     NaN  pool
# 728                liberty pool     NaN  pool
# 729            tottenville pool     NaN  pool
# 739            roy wilkins pool     NaN  pool
# 744                  faber pool     NaN  pool
# 745             kosciuszko pool     NaN  pool
# 771               john jay pool     NaN  pool
# 778       thomas jefferson pool     NaN  pool
# 787                crotona pool     NaN  pool
# 806              claremont pool     NaN  pool
# 808        commodore barry pool     NaN  pool
# 813                 fisher pool     NaN  pool
# 820     douglas and degraw pool     NaN  pool
# 828        tompkins square pool     NaN  pool
# 854        jackie robinson pool     NaN  pool
# 858   recreation center 54 pool     NaN  pool
# 881          marcus garvey pool     NaN  pool
# 900               bushwick pool     NaN  pool
# 906          tony dapolito pool     NaN  pool
# 909          west brighton pool     NaN  pool
# 912            fort totten pool     NaN  pool
# 933                  lyons pool     NaN  pool
# 939            sunset park pool     NaN  pool
# 940                 howard pool     NaN  pool
# 944                 haffen pool     NaN  pool
# 1329       sheltering arms pool     NaN  pool
# 1342                 mapes pool     NaN  pool
# 1381            windmuller pool     NaN  pool
# 1384       thompson street pool     NaN  pool
# 1399               chelsea pool     NaN  pool
# 1414            st. mary's pool     NaN  pool
# 1442            kosciuszko pool     NaN  pool
# 1485               crotona pool     NaN  pool
# 1495         lindower park pool     NaN  pool
# 1539             claremont pool     NaN  pool
# 1557                 ps 10 pool     NaN  pool
# 1558  brooklyn bridge park pool     NaN  pool
# 1614      marie curie park pool     NaN  pool
# 1625       edenwald houses pool     NaN  pool
#
#                                 match  ratio
# 140              (claremont pool, 85)     85
# 156   (recreation center 54 pool, 89)     89
# 179   (recreation center 54 pool, 89)     89
# 218           (metropolitan pool, 90)     90
# 309            (hansborough pool, 95)     95
# 352           (jhs 57/hs 26 pool, 95)     95
# 416              (claremont pool, 85)     85
# 482              (claremont pool, 85)     85
# 602                (mullaly pool, 95)     95
# 614          (hamilton fish pool, 95)     95
# 625                  (mapes pool, 95)     95
# 655             (betsy head pool, 95)     95
# 656        (glenwood houses pool, 95)     95
# 657                (crotona pool, 85)     85
# 691               (dry dock pool, 95)     95
# 694            (abe lincoln pool, 95)     95
# 704                (crotona pool, 85)     85
# 708       (david fox/ps 251 pool, 95)     95
# 716             (highbridge pool, 95)     95
# 724                 (wagner pool, 95)     95
# 728                (liberty pool, 95)     95
# 729            (tottenville pool, 95)     95
# 739            (roy wilkins pool, 95)     95
# 744                  (faber pool, 95)     95
# 745             (kosciuszko pool, 92)     92
# 771               (john jay pool, 95)     95
# 778       (thomas jefferson pool, 95)     95
# 787                (crotona pool, 95)     95
# 806              (claremont pool, 95)     95
# 808        (commodore barry pool, 95)     95
# 813                 (fisher pool, 95)     95
# 820     (douglas and degraw pool, 95)     95
# 828        (tompkins square pool, 95)     95
# 854        (jackie robinson pool, 95)     95
# 858   (recreation center 54 pool, 95)     95
# 881          (marcus garvey pool, 95)     95
# 900               (bushwick pool, 95)     95
# 906          (tony dapolito pool, 95)     95
# 909          (west brighton pool, 95)     95
# 912            (fort totten pool, 95)     95
# 933                  (lyons pool, 95)     95
# 939            (sunset park pool, 95)     95
# 940                 (howard pool, 95)     95
# 944                 (haffen pool, 95)     95
# 1329       (sheltering arms pool, 95)     95
# 1342                 (mapes pool, 85)     85
# 1381            (windmuller pool, 95)     95
# 1384       (thompson street pool, 95)     95
# 1399               (chelsea pool, 95)     95
# 1414            (st. mary's pool, 95)     95
# 1442            (kosciuszko pool, 97)     97
# 1485               (crotona pool, 85)     85
# 1495         (lindower park pool, 95)     95
# 1539             (claremont pool, 85)     85
# 1557                 (ps 10 pool, 95)     95
# 1558  (brooklyn bridge park pool, 95)     95
# 1614      (marie curie park pool, 95)     95
# 1625       (edenwald houses pool, 95)     95

# %%
print 'Recognized:'
print len(cParksMatched[pd.notnull(cParksMatched.SIGNNAME)]), '/', len(cParksMatched)
# Out:
# Recognized:
# 1360 / 1678

# %% [markdown]
# ## V. Beaches

# %%
beaches = [x.decode('utf8').lower() for x in pd.read_csv(PARQA + 'data/DPR_property/beaches.csv')['Name'].tolist()]

# %%
cParksMatched.ix[pd.isnull(cParksMatched.SIGNNAME) & cParksMatched.cleanName.str.contains('beach'), 'Type'] = 'beach'
# cParksMatched[pd.isnull(cParksMatched.SIGNNAME)]

# %%
cParksMatched.ix[cParksMatched.Type=='beach', 'match'] = \
cParksMatched.ix[cParksMatched.Type=='beach', 'cleanName'].apply(lambda x: process.extractOne(x, beaches))

# %%
cParksMatched.ix[cParksMatched.Type=='beach', 'SIGNNAME'] = \
cParksMatched.ix[cParksMatched.Type=='beach', 'match'].apply(lambda x: x[0])

cParksMatched.ix[cParksMatched.Type=='beach', 'ratio'] = \
cParksMatched.ix[cParksMatched.Type=='beach', 'match'].apply(lambda x: x[1])

# %%
cParksMatched[cParksMatched.Type=='beach']
# Out:
#                       Park Facility Name        Borough  \
# 117                      Beach - Midland  STATEN ISLAND
# 196                     Beach - Brighton       BROOKLYN
# 223                      Beach - Orchard          BRONX
# 361                    Beach - Manhattan       BROOKLYN
# 648                 Beach - Wolfe's Pond  STATEN ISLAND
# 685                        Beach - South  STATEN ISLAND
# 730                       Crescent Beach  STATEN ISLAND
# 785     Coney Island Beach and Boardwalk       BROOKLYN
# 1029           Golf Course - Dyker Beach       BROOKLYN
# 1217  Orchard Beach Park - Nature Center          BRONX
# 1298                 Beach - Cedar Grove  STATEN ISLAND
# 1600                Beach - Coney Island       BROOKLYN
# 1603                    Beach - Rockaway         QUEENS
#
#                                cleanName code  \
# 117                      beach - midland    R
# 196                     beach - brighton    B
# 223                      beach - orchard    X
# 361                    beach - manhattan    B
# 648                 beach - wolfe's pond    R
# 685                        beach - south    R
# 730                       crescent beach    R
# 785     coney island beach and boardwalk    B
# 1029           golf course - dyker beach    B
# 1217  orchard beach park - nature center    X
# 1298                 beach - cedar grove    R
# 1600                beach - coney island    B
# 1603                    beach - rockaway    Q
#
#                                      SIGNNAME BOROUGH   Type  \
# 117               orchard beach and promenade     NaN  beach
# 196                            brighton beach     NaN  beach
# 223               orchard beach and promenade     NaN  beach
# 361                           manhattan beach     NaN  beach
# 648                        wolfe's pond beach     NaN  beach
# 685                               south beach     NaN  beach
# 730               orchard beach and promenade     NaN  beach
# 785   coney island and coney island boardwalk     NaN  beach
# 1029                          manhattan beach     NaN  beach
# 1217                          manhattan beach     NaN  beach
# 1298                        cedar grove beach     NaN  beach
# 1600  coney island and coney island boardwalk     NaN  beach
# 1603              orchard beach and promenade     NaN  beach
#
#                                               match  ratio
# 117               (orchard beach and promenade, 85)     85
# 196                            (brighton beach, 95)     95
# 223               (orchard beach and promenade, 85)     85
# 361                           (manhattan beach, 95)     95
# 648                        (wolfe's pond beach, 95)     95
# 685                               (south beach, 95)     95
# 730               (orchard beach and promenade, 85)     85
# 785   (coney island and coney island boardwalk, 95)     95
# 1029                          (manhattan beach, 85)     85
# 1217                          (manhattan beach, 85)     85
# 1298                        (cedar grove beach, 95)     95
# 1600  (coney island and coney island boardwalk, 85)     85
# 1603              (orchard beach and promenade, 85)     85

# %%
print 'Recognized:'
print len(cParksMatched[pd.notnull(cParksMatched.SIGNNAME)]), '/', len(cParksMatched)
# Out:
# Recognized:
# 1373 / 1678

# %% [markdown]
# ## VI. School Playgrounds

# %%
schools = pd.read_csv(PARQA + 'data/DPR_property/school_playgrounds.csv')['PSID'].tolist()

# %%
cParksMatched.ix[pd.isnull(cParksMatched.SIGNNAME) & cParksMatched.cleanName.str.contains('ps '), 'Type'] = 'school'
# cParksMatched[pd.isnull(cParksMatched.SIGNNAME) & cParksMatched.cleanName.str.contains('ps')]
# cParksMatched[cParksMatched.cleanName.str.contains('ps')]

# %%
cParksMatched.ix[cParksMatched.Type=='school', 'match'] = \
cParksMatched.ix[cParksMatched.Type=='school', 'cleanName'].apply(lambda x: process.extractOne(x, schools))

# %%
cParksMatched.ix[cParksMatched.Type=='school', 'SIGNNAME'] = \
cParksMatched.ix[cParksMatched.Type=='school', 'match'].apply(lambda x: x[0])

cParksMatched.ix[cParksMatched.Type=='school', 'ratio'] = \
cParksMatched.ix[cParksMatched.Type=='school', 'match'].apply(lambda x: x[1])

# %%
cParksMatched[cParksMatched.Type=='school']
# Out:
#             Park Facility Name    Borough                 cleanName code  \
# 100       Evergreen Pk - PS 68     QUEENS      evergreen pk - ps 68    Q
# 185   Oakland Gardens - PS 203     QUEENS  oakland gardens - ps 203    Q
# 410      Athens Square - PS 17     QUEENS     athens square - ps 17    Q
# 464        Alfred Smith - PS 1  MANHATTAN       alfred smith - ps 1    M
# 983      Israel Putnam - PS 44   BROOKLYN     israel putnam - ps 44    B
# 1101         Gunn Park - PS 18     QUEENS         gunn park - ps 18    Q
# 1336      Wayanda Park - PS 34     QUEENS      wayanda park - ps 34    Q
# 1480      PS 4 Paradise Garden   BROOKLYN      ps 4 paradise garden    B
#
#        SIGNNAME BOROUGH    Type            match  ratio
# 100   Ps/is 187     NaN  school  (Ps/is 187, 85)     85
# 185   Ps/is 187     NaN  school  (Ps/is 187, 85)     85
# 410   Ps/is 187     NaN  school  (Ps/is 187, 85)     85
# 464   Ps/is 187     NaN  school  (Ps/is 187, 85)     85
# 983   Ps/is 187     NaN  school  (Ps/is 187, 85)     85
# 1101  Ps/is 187     NaN  school  (Ps/is 187, 85)     85
# 1336  Ps/is 187     NaN  school  (Ps/is 187, 85)     85
# 1480  Ps/is 187     NaN  school  (Ps/is 187, 85)     85

# %% [markdown]
# ## VII Golf Courses

# %%
golfs = [unicode(x).lower() for x in pd.read_csv(PARQA + 'data/DPR_property/DPR_GolfCourses_001.csv')['NAME'].tolist()]

# %%
cParksMatched.ix[pd.isnull(cParksMatched.SIGNNAME) & cParksMatched.cleanName.str.contains('golf '), 'Type'] = 'golf'

# %%
cParksMatched.ix[cParksMatched.Type=='golf', 'match'] = \
cParksMatched.ix[cParksMatched.Type=='golf', 'cleanName'].apply(lambda x: process.extractOne(x, golfs))

# %%
cParksMatched.ix[cParksMatched.Type=='golf', 'SIGNNAME'] = \
cParksMatched.ix[cParksMatched.Type=='golf', 'match'].apply(lambda x: x[0])

cParksMatched.ix[cParksMatched.Type=='golf', 'ratio'] = \
cParksMatched.ix[cParksMatched.Type=='golf', 'match'].apply(lambda x: x[1])

# %%
cParksMatched[cParksMatched.Type=='golf']
# Out:
#                                Park Facility Name        Borough  \
# 148                     Golf Course - South Shore  STATEN ISLAND
# 167                Clearview Park and Golf Course         QUEENS
# 310                         Golf Course - Kissena         QUEENS
# 467                  Golf Course - Clearview Park         QUEENS
# 495                     Golf Course - Silver Lake  STATEN ISLAND
# 497                      Golf Course - Douglaston         QUEENS
# 666                         Golf Course - Mosholu          BRONX
# 711       Golf Course - Golden Bear Driving Range         QUEENS
# 815                       South Shore Golf Course  STATEN ISLAND
# 1061  Golf Course - Randalls Island Driving Range      MANHATTAN
# 1121                     Golf Course - LaTourette  STATEN ISLAND
# 1332          Golf Course - Pelham and Split Rock          BRONX
# 1449             La Tourette Park and Golf Course  STATEN ISLAND
#
#                                         cleanName code  \
# 148                     golf course - south shore    R
# 167                clearview park and golf course    Q
# 310                         golf course - kissena    Q
# 467                  golf course - clearview park    Q
# 495                     golf course - silver lake    R
# 497                      golf course - douglaston    Q
# 666                         golf course - mosholu    X
# 711       golf course - golden bear driving range    Q
# 815                       south shore golf course    R
# 1061  golf course - randalls island driving range    M
# 1121                     golf course - latourette    R
# 1332          golf course - pelham and split rock    X
# 1449             la tourette park and golf course    R
#
#                       SIGNNAME BOROUGH  Type                           match  \
# 148    south shore golf course     NaN  golf   (south shore golf course, 95)
# 167      clearview golf course     NaN  golf     (clearview golf course, 95)
# 310   kissena park golf course     NaN  golf  (kissena park golf course, 95)
# 467      clearview golf course     NaN  golf     (clearview golf course, 95)
# 495    silver lake golf course     NaN  golf   (silver lake golf course, 95)
# 497     douglaston golf course     NaN  golf    (douglaston golf course, 95)
# 666        mosholu golf course     NaN  golf       (mosholu golf course, 95)
# 711      clearview golf course     NaN  golf     (clearview golf course, 85)
# 815    south shore golf course     NaN  golf  (south shore golf course, 100)
# 1061     clearview golf course     NaN  golf     (clearview golf course, 85)
# 1121   la tourette golf course     NaN  golf   (la tourette golf course, 93)
# 1332     clearview golf course     NaN  golf     (clearview golf course, 85)
# 1449   la tourette golf course     NaN  golf   (la tourette golf course, 95)
#
#       ratio
# 148      95
# 167      95
# 310      95
# 467      95
# 495      95
# 497      95
# 666      95
# 711      85
# 815     100
# 1061     85
# 1121     93
# 1332     85
# 1449     95

# %%
print 'Recognized:'
print len(cParksMatched[pd.notnull(cParksMatched.SIGNNAME)]), '/', len(cParksMatched)
# Out:
# Recognized:
# 1394 / 1678

# %% [markdown]
# ## VI. Park Names

# %%
parkNames = gp.read_file(PARQA + 'data/parks_computed.geojson')[['SIGNNAME','BOROUGH']].drop_duplicates()
parkNames['SIGNNAME'] = parkNames['SIGNNAME'].str.lower()

# %%
ofParks = [unicode(x) for x in parkNames['SIGNNAME'].tolist()]

# ofParks = {k:[unicode(x) for x in list(v)] for k,v in parkNames.groupby("BOROUGH")["SIGNNAME"]}

# tmp = []
# for v in ofParks.values():
#     tmp.extend(v)
# ofParks['?'] = tmp   #['???'] ### to mark parks with unspecified Borough

# %%
cParksMatched.ix[pd.isnull(cParksMatched.SIGNNAME), 'Type'] = 'other'

# %%
### ATTENTION, TAKES ~5 MINUTES

cParksMatched.ix[cParksMatched.Type=='other', 'match'] = \
cParksMatched[cParksMatched.Type=='other'].apply(lambda x: process.extractOne(x.cleanName, ofParks), 1)

# %%
cParksMatched.ix[cParksMatched.Type=='other', 'SIGNNAME'] = \
cParksMatched.ix[cParksMatched.Type=='other', 'match'].apply(lambda x: x[0])

cParksMatched.ix[cParksMatched.Type=='other', 'ratio'] = \
cParksMatched.ix[cParksMatched.Type=='other', 'match'].apply(lambda x: x[1])

# %%
cParksMatched[cParksMatched.Type=='other']
# Out:
#                                      Park Facility Name        Borough  \
# 0                   Geo Soilan Park - Battery Park City      MANHATTAN
# 8                                 William H Seward Park      MANHATTAN
# 18                                  St Catherine's Park      MANHATTAN
# 35                   Louis J Valentino Jr Park and Pier       BROOKLYN
# 43                                   Hells Kitchen Park      MANHATTAN
# 45                          Brooklyn Civic Center Parks       BROOKLYN
# 51                              J J Byrne Memorial Park       BROOKLYN
# 57                                   Sherman Creek Park      MANHATTAN
# 58                                         Kolbert Park       BROOKLYN
# 77                                       Alice Kornegay      MANHATTAN
# 79                 Recreation Center - Thomas Jefferson      MANHATTAN
# 83                              Hillside Park - JHS 172         QUEENS
# 91                                         Maurice Park         QUEENS
# 101                            Blue Heron Park Preserve  STATEN ISLAND
# 105                     Recreation Center - Hansborough      MANHATTAN
# 108                         Riverside Park - Skate Park      MANHATTAN
# 118     Recreation Center - Fort Hamilton Senior Center       BROOKLYN
# 119                                      High Line Park      MANHATTAN
# 136                        Recreation Center - Red Hook       BROOKLYN
# 141                      Recreation Center - St. John's       BROOKLYN
# 143                         Recreation Center - Chelsea      MANHATTAN
# 149                                     East River Park      MANHATTAN
# 150             Weeping Beech - Margaret I Carmen Green         QUEENS
# 161                                    Bronx River Park          BRONX
# 165                     Recreation Center - Brownsville       BROOKLYN
# 171                                       Rockaway Park         QUEENS
# 172   Riverside Park - Running Track and 78th St Bal...      MANHATTAN
# 173                                Wright Brothers Park      MANHATTAN
# 183                            Monsignor Mcgolrick Park       BROOKLYN
# 189                                  J Hood Wright Park      MANHATTAN
# ...                                                 ...            ...
# 1527                                         Park Strip       BROOKLYN
# 1528                                Hunter's Point Park         QUEENS
# 1531                     McCarren Park Ice Skating Rink       BROOKLYN
# 1550                               Riverbank State Park      MANHATTAN
# 1568                   Riverside Park - Baseball Fields         QUEENS
# 1569                        Roberto Clemente State Park          BRONX
# 1570                            Kosciusko Street Garden       BROOKLYN
# 1580                            West 87th Street Garden      MANHATTAN
# 1582                                          I Am Park          BRONX
# 1583         Aqueduct Walk - Frisch Field In Bronx Park          BRONX
# 1585                     Recreation Center - A.R.R.O.W.         QUEENS
# 1587                      Metro North Community Gardens         QUEENS
# 1591                     Recreation Center - Highbridge      MANHATTAN
# 1597            Weeping Beech - Margaret I Carmen Green      MANHATTAN
# 1602                      St Nicholas - Olive St Garden       BROOKLYN
# 1605                                      Risse St Park          BRONX
# 1617                    Alley Pond Park - Nature Center            NaN
# 1618                                   Hook Creek Marsh         QUEENS
# 1623                     St Nicholas - Powers St Garden       BROOKLYN
# 1626                              Hendrick I Lott House       BROOKLYN
# 1627                              William H Seward Park       BROOKLYN
# 1630  Recreation Center - Betsy Head CBO- Amboy Neig...       BROOKLYN
# 1642                    El Puente - Earth Spirit Garden       BROOKLYN
# 1649                        Starlight Park - Peace Park          BRONX
# 1656                                    A Child's Place       BROOKLYN
# 1662                                    Recreation Area      MANHATTAN
# 1670                        Hunt's Point Riverside Park      MANHATTAN
# 1673                           West 104th Street Garden      MANHATTAN
# 1674                    Recreation Center - Haffen Park          BRONX
# 1675                                      New Ballfield  STATEN ISLAND
#
#                                               cleanName code  \
# 0                   geo soilan park - battery park city    M
# 8                                 william h seward park    M
# 18                                  st catherine's park    M
# 35                   louis j valentino jr park and pier    B
# 43                                   hells kitchen park    M
# 45                          brooklyn civic center parks    B
# 51                              j j byrne memorial park    B
# 57                                   sherman creek park    M
# 58                                         kolbert park    B
# 77                                       alice kornegay    M
# 79                 recreation center - thomas jefferson    M
# 83                              hillside park - jhs 172    Q
# 91                                         maurice park    Q
# 101                            blue heron park preserve    R
# 105                     recreation center - hansborough    M
# 108                         riverside park - skate park    M
# 118     recreation center - fort hamilton senior center    B
# 119                                      high line park    M
# 136                        recreation center - red hook    B
# 141                      recreation center - st. john's    B
# 143                         recreation center - chelsea    M
# 149                                     east river park    M
# 150             weeping beech - margaret i carmen green    Q
# 161                                    bronx river park    X
# 165                     recreation center - brownsville    B
# 171                                       rockaway park    Q
# 172   riverside park - running track and 78th st bal...    M
# 173                                wright brothers park    M
# 183                            monsignor mcgolrick park    B
# 189                                  j hood wright park    M
# ...                                                 ...  ...
# 1527                                         park strip    B
# 1528                                hunter's point park    Q
# 1531                     mccarren park ice skating rink    B
# 1550                               riverbank state park    M
# 1568                   riverside park - baseball fields    Q
# 1569                        roberto clemente state park    X
# 1570                            kosciusko street garden    B
# 1580                            west 87th street garden    M
# 1582                                          i am park    X
# 1583         aqueduct walk - frisch field in bronx park    X
# 1585                     recreation center - a.r.r.o.w.    Q
# 1587                      metro north community gardens    Q
# 1591                     recreation center - highbridge    M
# 1597            weeping beech - margaret i carmen green    M
# 1602                      st nicholas - olive st garden    B
# 1605                                      risse st park    X
# 1617                    alley pond park - nature center  NaN
# 1618                                   hook creek marsh    Q
# 1623                     st nicholas - powers st garden    B
# 1626                              hendrick i lott house    B
# 1627                              william h seward park    B
# 1630  recreation center - betsy head cbo- amboy neig...    B
# 1642                    el puente - earth spirit garden    B
# 1649                        starlight park - peace park    X
# 1656                                    a child's place    B
# 1662                                    recreation area    M
# 1670                        hunt's point riverside park    M
# 1673                           west 104th street garden    M
# 1674                    recreation center - haffen park    X
# 1675                                      new ballfield    R
#
#                                       SIGNNAME BOROUGH   Type  \
# 0                            battery park city     NaN  other
# 8                                         park     NaN  other
# 18                        st. catherine's park     NaN  other
# 35                           queensbridge park     NaN  other
# 43                         hell's kitchen park     NaN  other
# 45                                        park     NaN  other
# 51                                        park     NaN  other
# 57                               sherman creek     NaN  other
# 58                                        park     NaN  other
# 77                     alice kornegay triangle     NaN  other
# 79                    red hook recreation area     NaN  other
# 83                                        park     NaN  other
# 91                                        park     NaN  other
# 101                                       park     NaN  other
# 105              hansborough recreation center     NaN  other
# 108                             riverside park     NaN  other
# 118                   red hook recreation area     NaN  other
# 119                                       park     NaN  other
# 136                       recreation center 54     NaN  other
# 141               st. john's recreation center     NaN  other
# 143                  chelsea recreation center     NaN  other
# 149                                       park     NaN  other
# 150   margaret i. carman green - weeping beech     NaN  other
# 161                        bronx river parkway     NaN  other
# 165                         marcy green center     NaN  other
# 171                                       park     NaN  other
# 172                             riverside park     NaN  other
# 173                                       park     NaN  other
# 183                                       park     NaN  other
# 189                        j. hood wright park     NaN  other
# ...                                        ...     ...    ...
# 1527                                      park     NaN  other
# 1528                 hunter's point south park     NaN  other
# 1531                                      park     NaN  other
# 1550                                      park     NaN  other
# 1568                            riverside park     NaN  other
# 1569                                      park     NaN  other
# 1570                  kosciuszko street garden     NaN  other
# 1580                      w 87th street garden     NaN  other
# 1582                                 i-am-park     NaN  other
# 1583                                bronx park     NaN  other
# 1585                      recreation center 54     NaN  other
# 1587                             unity gardens     NaN  other
# 1591                           highbridge park     NaN  other
# 1597  margaret i. carman green - weeping beech     NaN  other
# 1602           st. nicholas - olive st. garden     NaN  other
# 1605                                      park     NaN  other
# 1617                                      park     NaN  other
# 1618                  red hook recreation area     NaN  other
# 1623          st. nicholas - powers st. garden     NaN  other
# 1626                    hendrick i. lott house     NaN  other
# 1627                                      park     NaN  other
# 1630                 amboy neighborhood center     NaN  other
# 1642                       earth spirit garden     NaN  other
# 1649                            starlight park     NaN  other
# 1656                 hunter's point south park     NaN  other
# 1662                         recreational area     NaN  other
# 1670                hunts point riverside park     NaN  other
# 1673                     w 104th street garden     NaN  other
# 1674                               haffen park     NaN  other
# 1675          william f. passannante ballfield     NaN  other
#
#                                                match  ratio
# 0                            (battery park city, 90)     90
# 8                                         (park, 90)     90
# 18                        (st. catherine's park, 97)     97
# 35                           (queensbridge park, 85)     85
# 43                         (hell's kitchen park, 97)     97
# 45                                        (park, 90)     90
# 51                                        (park, 90)     90
# 57                               (sherman creek, 95)     95
# 58                                        (park, 90)     90
# 77                     (alice kornegay triangle, 90)     90
# 79                    (red hook recreation area, 85)     85
# 83                                        (park, 90)     90
# 91                                        (park, 90)     90
# 101                                       (park, 90)     90
# 105              (hansborough recreation center, 95)     95
# 108                             (riverside park, 90)     90
# 118                   (red hook recreation area, 85)     85
# 119                                       (park, 90)     90
# 136                       (recreation center 54, 87)     87
# 141               (st. john's recreation center, 95)     95
# 143                  (chelsea recreation center, 95)     95
# 149                                       (park, 90)     90
# 150   (margaret i. carman green - weeping beech, 92)     92
# 161                        (bronx river parkway, 91)     91
# 165                         (marcy green center, 85)     85
# 171                                       (park, 90)     90
# 172                             (riverside park, 90)     90
# 173                                       (park, 90)     90
# 183                                       (park, 90)     90
# 189                        (j. hood wright park, 97)     97
# ...                                              ...    ...
# 1527                                      (park, 90)     90
# 1528                 (hunter's point south park, 95)     95
# 1531                                      (park, 90)     90
# 1550                                      (park, 90)     90
# 1568                            (riverside park, 90)     90
# 1569                                      (park, 90)     90
# 1570                  (kosciuszko street garden, 98)     98
# 1580                      (w 87th street garden, 93)     93
# 1582                                (i-am-park, 100)    100
# 1583                                (bronx park, 90)     90
# 1585                      (recreation center 54, 87)     87
# 1587                             (unity gardens, 90)     90
# 1591                           (highbridge park, 85)     85
# 1597  (margaret i. carman green - weeping beech, 92)     92
# 1602           (st. nicholas - olive st. garden, 97)     97
# 1605                                      (park, 90)     90
# 1617                                      (park, 90)     90
# 1618                  (red hook recreation area, 85)     85
# 1623          (st. nicholas - powers st. garden, 97)     97
# 1626                    (hendrick i. lott house, 98)     98
# 1627                                      (park, 90)     90
# 1630                 (amboy neighborhood center, 90)     90
# 1642                       (earth spirit garden, 90)     90
# 1649                            (starlight park, 90)     90
# 1656                 (hunter's point south park, 85)     85
# 1662                         (recreational area, 94)     94
# 1670                (hunts point riverside park, 98)     98
# 1673                     (w 104th street garden, 93)     93
# 1674                               (haffen park, 90)     90
# 1675          (william f. passannante ballfield, 85)     85
#
# [284 rows x 9 columns]

# %%
cParksMatched.to_csv(PARQA + 'data/311/Ontology2_unverified.csv',encoding='utf8')
